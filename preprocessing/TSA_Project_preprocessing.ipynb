# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

def fill_missing_calendar_dates(df, date_column):
    df[date_column] = pd.to_datetime(df[date_column])
    df.set_index(date_column, inplace=True)
    full_date_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')
    df_filled = df.reindex(full_date_range, method='ffill')
    df_filled.reset_index(inplace=True)
    df_filled.rename(columns={'index': date_column}, inplace=True)

    return df_filled


file_path = '/content/AADHARHFC_NS.csv'
data = pd.read_csv(file_path)


data_filled = fill_missing_calendar_dates(data, 'Date')

data_filled.to_csv('/content/AADHARHFC_NS_updated.csv', index=False)

# %%
df = pd.read_csv('/content/AADHARHFC_NS_updated.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       150 non-null    object
#  1   Open       150 non-null    float64
#  2   High       150 non-null    float64
#  3   Low        150 non-null    float64
#  4   Close      150 non-null    float64
#  5   Adj Close  150 non-null    float64
#  6   Volume     150 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 8.3+ KB

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv('/content/AADHARHFC_NS.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       103 non-null    object
#  1   Open       103 non-null    float64
#  2   High       103 non-null    float64
#  3   Low        103 non-null    float64
#  4   Close      103 non-null    float64
#  5   Adj Close  103 non-null    float64
#  6   Volume     103 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 5.8+ KB

# %%
import os
import pandas as pd

def fill_missing_calendar_dates(df, date_column):
    df[date_column] = pd.to_datetime(df[date_column])
    df.set_index(date_column, inplace=True)
    full_date_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')
    df_filled = df.reindex(full_date_range, method='ffill')
    df_filled.reset_index(inplace=True)
    df_filled.rename(columns={'index': date_column}, inplace=True)
    return df_filled

input_folder = '/content/drive/MyDrive/equity_data'
output_folder = '/content/drive/MyDrive/equity_data/equity_data_updated'


os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.endswith('.csv'):
        file_path = os.path.join(input_folder, filename)
        data = pd.read_csv(file_path)
        data_filled = fill_missing_calendar_dates(data, 'Date')
        output_file_path = os.path.join(output_folder, filename)
        data_filled.to_csv(output_file_path, index=False)
        print(f"Updated: {filename}")
# Out:
# Updated: SUDARSCHEM_NS.csv
# Updated: USHAMART_NS.csv
# Updated: NEULANDLAB_NS.csv
# Updated: BANDHANBNK_NS.csv
# Updated: AGI_NS.csv
# Updated: KIRLPNU_NS.csv
# Updated: NAM-INDIA_NS.csv
# Updated: DODLA_NS.csv
# Updated: BOROLTD_NS.csv
# Updated: HCC_NS.csv
# Updated: HINDWAREAP_NS.csv
# Updated: BSE_NS.csv
# Updated: NETWORK18_NS.csv
# Updated: IXIGO_NS.csv
# Updated: NETWEB_NS.csv
# Updated: SONATSOFTW_NS.csv
# Updated: TRITURBINE_NS.csv
# Updated: EMBDL_NS.csv
# Updated: YATHARTH_NS.csv
# Updated: JAICORPLTD_NS.csv
# Updated: JMFINANCIL_NS.csv
# Updated: TV18BRDCST_NS.csv
# Updated: EDELWEISS_NS.csv
# Updated: NUVAMA_NS.csv
# Updated: RAJESHEXPO_NS.csv
# Updated: WOCKPHARMA_NS.csv
# Updated: DBREALTY_NS.csv
# Updated: GMDCLTD_NS.csv
# Updated: BLUEJET_NS.csv
# Updated: JAMNAAUTO_NS.csv
# Updated: CRISIL_NS.csv
# Updated: MOTILALOFS_NS.csv
# Updated: NATIONALUM_NS.csv
# Updated: PERSISTENT_NS.csv
# Updated: GRANULES_NS.csv
# Updated: TEXRAIL_NS.csv
# Updated: IPCALAB_NS.csv
# ...

# %%
import os
import pandas as pd

def fill_missing_calendar_dates(df, date_column):
    df[date_column] = pd.to_datetime(df[date_column])
    df.set_index(date_column, inplace=True)
    full_date_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')
    df_filled = df.reindex(full_date_range, method='ffill')
    df_filled.reset_index(inplace=True)
    df_filled.rename(columns={'index': date_column}, inplace=True)
    return df_filled

input_folder = '/content/drive/MyDrive/equity_data_BSE'
output_folder = '/content/drive/MyDrive/equity_data_BSE/equity_data_BSE_updated'


os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.endswith('.csv'):
        file_path = os.path.join(input_folder, filename)
        data = pd.read_csv(file_path)
        data_filled = fill_missing_calendar_dates(data, 'Date')
        output_file_path = os.path.join(output_folder, filename)
        data_filled.to_csv(output_file_path, index=False)
        print(f"Updated: {filename}")
# Out:
# Updated: RTNPOWER_BO.csv
# Updated: INFINITE_BO.csv
# Updated: DEN_BO.csv
# Updated: ASTEC_BO.csv
# Updated: AQUA_BO.csv
# Updated: DLINKINDIA_BO.csv
# Updated: JSWENERGY_BO.csv
# Updated: COROENGG_BO.csv
# Updated: GODREJPROP_BO.csv
# Updated: DBCORP_BO.csv
# Updated: MBLINFRA_BO.csv
# Updated: DQE_BO.csv
# Updated: VASCONEQ_BO.csv
# Updated: JUBLFOOD_BO.csv
# Updated: DBREALTY_BO.csv
# Updated: THANGAMAYL_BO.csv
# Updated: HATHWAY_BO.csv
# Updated: EMMBI_BO.csv
# Updated: SGJHL_BO.csv
# Updated: GOENKA_BO.csv
# Updated: ARSSINFRA_BO.csv
# Updated: TEXMOPIPES_BO.csv
# Updated: SUNDARAM_BO.csv
# Updated: TALWALKARS_BO.csv
# Updated: ROSSELLIND_BO.csv
# Updated: MANINFRA_BO.csv
# Updated: GBGLOBAL_BO.csv
# Updated: IL&FSTRANS_BO.csv
# Updated: JPINFRATEC_BO.csv
# Updated: PERSISTENT_BO.csv
# Updated: KECL_BO.csv
# Updated: ISFT_BO.csv
# Updated: KCPSUGIND_BO.csv
# Updated: TECHNOFAB_BO.csv
# Updated: TARAPUR_BO.csv
# Updated: AHLWEST_BO.csv
# Updated: EMAMIPAP_BO.csv
# ...

# %%
import os
import pandas as pd

def fill_missing_calendar_dates(df, date_column):
    df[date_column] = pd.to_datetime(df[date_column])
    df.set_index(date_column, inplace=True)
    full_date_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')
    df_filled = df.reindex(full_date_range, method='ffill')
    df_filled.reset_index(inplace=True)
    df_filled.rename(columns={'index': date_column}, inplace=True)
    return df_filled

input_folder = '/content/drive/MyDrive/mineral_data'
output_folder = '/content/drive/MyDrive/mineral_data/mineral_data_updated'


os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.endswith('.csv'):
        file_path = os.path.join(input_folder, filename)
        data = pd.read_csv(file_path)
        data_filled = fill_missing_calendar_dates(data, 'Date')
        output_file_path = os.path.join(output_folder, filename)
        data_filled.to_csv(output_file_path, index=False)
        print(f"Updated: {filename}")
# Out:
# Updated: CL_F.csv
# Updated: NG_F.csv
# Updated: BZ_F.csv
# Updated: HO_F.csv
# Updated: RB_F.csv
# Updated: GC_F.csv
# Updated: SI_F.csv
# Updated: HG_F.csv
# Updated: PL_F.csv
# Updated: PA_F.csv
# Updated: ALI_F.csv
# Updated: ZNC_F.csv
